# %%
import pandas as pd
import pylab as pl
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('private-sector_ind.csv')
df.head()
df.loc[df['Indicator Name']=='Start-up procedures to register a business (number)']
# Out:
#     Country Name Country ISO3  Year  \
# 427        India          IND  2019
# 428        India          IND  2018
# 429        India          IND  2017
# 430        India          IND  2016
# 431        India          IND  2015
# 432        India          IND  2014
# 433        India          IND  2013
#
#                                         Indicator Name Indicator Code Value
# 427  Start-up procedures to register a business (nu...    IC.REG.PROC    10
# 428  Start-up procedures to register a business (nu...    IC.REG.PROC    10
# 429  Start-up procedures to register a business (nu...    IC.REG.PROC    12
# 430  Start-up procedures to register a business (nu...    IC.REG.PROC    14
# 431  Start-up procedures to register a business (nu...    IC.REG.PROC    14
# 432  Start-up procedures to register a business (nu...    IC.REG.PROC    15
# 433  Start-up procedures to register a business (nu...    IC.REG.PROC    14
